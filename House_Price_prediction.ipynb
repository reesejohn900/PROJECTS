# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/train.csv')
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_train.isna().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
#                  ...
# CentralAir          0
# SaleCondition       0
# Heating             0
# TotalBsmtSF         0
# Id                  0
# Length: 81, dtype: int64

# %%
  df_train['LotFrontage'].fillna(value=np.mean(df_train['LotFrontage']),inplace=True)

# %%
matrix_corr = df_train.corr()
matrix_corr['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.334901
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
df_train['MasVnrType'].dtype
# Out:
# dtype('O')

# %%
columns_list = df_train.columns

# %%
objects_dtype=[]
for column in columns_list:
  if df_train[column].dtype =='O':
    objects_dtype.append(column)

# %%
objects_dtype
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df_train['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
missing = pd.DataFrame(df_train.isna().sum().sort_values(ascending=False))

# %%
missing = missing.iloc[:18]

# %%
df_train.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)

# %%
df_train.drop(['MasVnrType','Id'],axis=1,inplace=True)

# %%
df_train['Electrical'].fillna(value='SBrkr',inplace=True)

# %%
df_train['MasVnrArea'].fillna(value=np.mean(df_train['MasVnrArea']),inplace=True)

# %%
df_train['BsmtQual'].fillna(value='Gd',inplace=True)

# %%
df_train['BsmtCond'].fillna(value='TA',inplace=True)

# %%
df_train['BsmtFinType1'].fillna(value='GLQ',inplace=True)

# %%
df_train['BsmtFinType2'].fillna(value='Unf',inplace=True)

# %%
df_train['BsmtExposure'].fillna(value='No',inplace=True)

# %%
df_train['GarageQual'].fillna('TA',inplace=True)

# %%
df_train['GarageFinish'].fillna('RFn',inplace=True)

# %%
df_train['GarageYrBlt'].fillna(np.mean(df_train['GarageYrBlt']),inplace=True)

# %%
df_train['GarageType'].fillna('Attchd',inplace=True)

# %%
df_train['GarageCond'].fillna("TA",inplace=True)

# %%
df_train.drop(['BedroomAbvGr','ScreenPorch','PoolArea','MoSold','3SsnPorch','BsmtFinSF2','BsmtHalfBath','MiscVal','LowQualFinSF','YrSold','OverallCond','MSSubClass'],axis=1,inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   LotFrontage    1460 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  Condition1     1460 non-null   object
#  11  Condition2     1460 non-null   object
#  12  BldgType       1460 non-null   object
#  13  HouseStyle     1460 non-null   object
#  14  OverallQual    1460 non-null   int64
#  15  YearBuilt      1460 non-null   int64
#  16  YearRemodAdd   1460 non-null   int64
# ...

# %%
x = df_train.drop('SalePrice',axis=1)
y = df_train['SalePrice']

# %%
x['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
x_num = pd.get_dummies(data=x[list(x.columns)])

# %%
x_num.head()
# Out:
#    LotFrontage  LotArea  ...  SaleCondition_Normal  SaleCondition_Partial
# 0         65.0     8450  ...                     1                      0
# 1         80.0     9600  ...                     1                      0
# 2         68.0    11250  ...                     1                      0
# 3         60.0     9550  ...                     0                      0
# 4         84.0    14260  ...                     1                      0
#
# [5 rows x 254 columns]

# %%
x_num.shape
# Out:
# (1460, 254)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(x_num,x_num['OverallQual']):
  strat_train_set = x_num.loc[train_index]
  strat_test_set = x_num.loc[test_index]

# %%
train_label = y.loc[train_index]
test_label = y.loc[test_index]

# %%
strat_train_set.shape,train_label.shape
# Out:
# ((1168, 254), (1168,))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(strat_train_set)
x_test = scaler.transform(strat_test_set)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()
model.add(Dense(254))

model.add(Dense(100))
model.add(Dense(1))

model.compile(loss = 'mean_squared_logarithmic_error',
              optimizer = 'adam',
              metrics = ['mean_squared_logarithmic_error'
])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
modelcheckpoint = ModelCheckpoint(filepath='/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/model_5.h5',save_best_only=True,monitor='val_loss',mode='min',verbose=1)

# %%
model.fit(x = x_train,y=train_label,batch_size=32,epochs=100,validation_data=(x_test,test_label),callbacks=[modelcheckpoint])
# Out:
# Epoch 1/100
# 37/37 [==============================] - 1s 8ms/step - loss: 78.0349 - mean_squared_logarithmic_error: 78.0349 - val_loss: 55.2489 - val_mean_squared_logarithmic_error: 55.2489
# Epoch 2/100
# 37/37 [==============================] - 0s 4ms/step - loss: 47.7738 - mean_squared_logarithmic_error: 47.7738 - val_loss: 41.4175 - val_mean_squared_logarithmic_error: 41.4175
# Epoch 3/100
# 37/37 [==============================] - 0s 4ms/step - loss: 37.4706 - mean_squared_logarithmic_error: 37.4706 - val_loss: 33.7314 - val_mean_squared_logarithmic_error: 33.7314
# Epoch 4/100
# 37/37 [==============================] - 0s 4ms/step - loss: 31.1038 - mean_squared_logarithmic_error: 31.1038 - val_loss: 28.5094 - val_mean_squared_logarithmic_error: 28.5094
# Epoch 5/100
# 37/37 [==============================] - 0s 4ms/step - loss: 26.5985 - mean_squared_logarithmic_error: 26.5985 - val_loss: 24.6736 - val_mean_squared_logarithmic_error: 24.6736
# Epoch 6/100
# ...

# %%
model_2 = Sequential()
model_2.add(Dense(254))

model_2.add(Dense(100))
model_2.add(Dense(1))

model_2.compile(loss = 'mean_squared_logarithmic_error',
              optimizer = 'adam',
              metrics = ['mean_squared_logarithmic_error'
])

# %%
model_2.fit(x = x_train,y=train_label,batch_size=32,epochs=300,validation_data=(x_test,test_label),callbacks=[modelcheckpoint])
# Out:
# Epoch 1/300
# 21/37 [================>.............] - ETA: 0s - loss: 84.4780 - mean_squared_logarithmic_error: 84.4780
# Epoch 00001: val_loss improved from inf to 53.63148, saving model to /content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/model_5.h5
# 37/37 [==============================] - 1s 9ms/step - loss: 73.8555 - mean_squared_logarithmic_error: 73.8555 - val_loss: 53.6315 - val_mean_squared_logarithmic_error: 53.6315
# Epoch 2/300
# 26/37 [====================>.........] - ETA: 0s - loss: 48.0316 - mean_squared_logarithmic_error: 48.0316
# Epoch 00002: val_loss improved from 53.63148 to 40.24161, saving model to /content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/model_5.h5
# 37/37 [==============================] - 0s 6ms/step - loss: 46.3989 - mean_squared_logarithmic_error: 46.3989 - val_loss: 40.2416 - val_mean_squared_logarithmic_error: 40.2416
# Epoch 3/300
# ...

# %%
model_3 = Sequential()
model_3.add(Dense(254))

model_3.add(Dense(100))
model_3.add(Dense(1))

model_3.compile(loss = 'mean_squared_logarithmic_error',
              optimizer = 'adam',
              metrics = ['mean_squared_logarithmic_error'
])

# %%
model_3.fit(x = x_train,y=train_label,batch_size=32,epochs=600,validation_data=(x_test,test_label),callbacks=[modelcheckpoint])
# Out:
# Epoch 1/600
# 32/37 [========================>.....] - ETA: 0s - loss: 79.5979 - mean_squared_logarithmic_error: 79.5979
# Epoch 00001: val_loss improved from inf to 54.73042, saving model to /content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/model_4.h5
# 37/37 [==============================] - 1s 11ms/step - loss: 76.8570 - mean_squared_logarithmic_error: 76.8570 - val_loss: 54.7304 - val_mean_squared_logarithmic_error: 54.7304
# Epoch 2/600
# 31/37 [========================>.....] - ETA: 0s - loss: 48.0227 - mean_squared_logarithmic_error: 48.0227
# Epoch 00002: val_loss improved from 54.73042 to 40.66105, saving model to /content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/model_4.h5
# 37/37 [==============================] - 0s 6ms/step - loss: 47.1161 - mean_squared_logarithmic_error: 47.1161 - val_loss: 40.6611 - val_mean_squared_logarithmic_error: 40.6611
# Epoch 3/600
# ...

# %%
model_4 = Sequential()
model_4.add(Dense(254))

model_4.add(Dense(50))
model_4.add(Dense(50))
model_4.add(Dense(1))

model_4.compile(loss = 'mean_squared_logarithmic_error',
              optimizer = 'adam',
              metrics = ['mean_squared_logarithmic_error'
])

# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.read_csv('/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
df_test.drop(['BedroomAbvGr','ScreenPorch','PoolArea','MoSold','3SsnPorch','BsmtFinSF2','BsmtHalfBath','MiscVal','LowQualFinSF','YrSold','OverallCond','MSSubClass'],axis=1,inplace=True)
df_test.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)

# %%
df_test.drop(['MasVnrType','Id'],axis=1,inplace=True)

# %%
df_test['GarageCond'].fillna("TA",inplace=True)
df_test['GarageType'].fillna('Attchd',inplace=True)
df_test['GarageYrBlt'].fillna(np.mean(df_test['GarageYrBlt']),inplace=True)
df_test['GarageFinish'].fillna('RFn',inplace=True)
df_test['GarageQual'].fillna('TA',inplace=True)
df_test['BsmtExposure'].fillna(value='No',inplace=True)
df_test['BsmtFinType2'].fillna(value='Unf',inplace=True)
df_test['BsmtFinType1'].fillna(value='GLQ',inplace=True)
df_test['BsmtCond'].fillna(value='TA',inplace=True)
df_test['BsmtQual'].fillna(value='Gd',inplace=True)
df_test['MasVnrArea'].fillna(value=np.mean(df_test['MasVnrArea']),inplace=True)
df_test['Electrical'].fillna(value='SBrkr',inplace=True)
df_test['LotFrontage'].fillna(value=np.mean(df_test['LotFrontage']),inplace=True)
df_test['MSZoning'].fillna('RL',inplace=True)
df_test['Functional'].fillna('Typ',inplace=True)
df_test['BsmtFullBath'].fillna(0.0,inplace=True)
df_test['Utilities'].fillna('AllPub',inplace=True)
df_test['GarageCars'].fillna(2.0,inplace=True)
df_test['KitchenQual'].fillna('TA',inplace=True)
df_test['Exterior1st'].fillna('VinylSd',inplace=True)
df_test['Exterior2nd'].fillna('VinylSd',inplace=True)
df_test['TotalBsmtSF'].fillna(np.mean(df_test['TotalBsmtSF']),inplace=True)
df_test['GarageArea'].fillna(np.mean(df_test['GarageArea']),inplace=True)
df_test['BsmtUnfSF'].fillna(np.mean(df_test['BsmtUnfSF']),inplace=True)
df_test['SaleType'].fillna('WD',inplace=True)
df_test['BsmtFinSF1'].fillna(np.mean(df_test['BsmtFinSF1']),inplace=True)

# %%
test_num = pd.get_dummies(data=df_test[list(x.columns)])

# %%
test_num.shape
# Out:
# (1459, 238)

# %%
x_num.shape
# Out:
# (1460, 254)

# %%
train_columns = set(x_num.columns)

# %%
test_columns = set(test_num.columns)

# %%
l1 = train_columns.difference(test_columns)

# %%
for column in l1:
  test_num[column]=0

# %%
df = df.reindex(sorted(), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-3574d5e5be1e> in <module>()
# ----> 1 df = df.reindex(sorted(), axis=1)
#
# NameError: name 'df' is not defined

# %%
test_columns_sorted = test_num.reindex(columns=list(x_num.columns))

# %%
test_scaled = scaler.transform(test_columns_sorted)

# %%
from tensorflow.keras.models import load_model

# %%
best_model = load_model('/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/model_4.h5')

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 254)               64770
#
#  dense_1 (Dense)             (None, 100)               25500
#
#  dense_2 (Dense)             (None, 1)                 101
#
# ...
# Total params: 90,371
# Trainable params: 90,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction = best_model.predict(test_scaled)

# %%
type(prediction)
# Out:
# numpy.ndarray

# %%
prediction.shape
# Out:
# (1459, 1)

# %%
prediction = prediction.reshape((1459))

# %%
test=pd.read_csv('/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
submission =pd.DataFrame(test['Id'])

# %%
submission['SalePrice'] = list(prediction)

# %%
submission.head(20)
# Out:
#       Id      SalePrice
# 0   1461  119050.679688
# 1   1462  154057.484375
# 2   1463  182993.718750
# 3   1464  192903.984375
# 4   1465  203027.359375
# 5   1466  171889.828125
# 6   1467  175815.812500
# 7   1468  165325.140625
# 8   1469  199704.812500
# 9   1470  131182.984375
# 10  1471  156138.703125
# 11  1472  109943.718750
# 12  1473   98683.320312
# 13  1474  141461.953125
# 14  1475   97565.390625
# 15  1476  357262.312500
# 16  1477  241346.484375
# 17  1478  329789.343750
# 18  1479  328614.875000
# 19  1480  435217.281250

# %%
submission.to_csv('/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/submission-2.csv',index=False)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfg = RandomForestRegressor(n_estimators=1000)
rfg.fit(x_train,train_label)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
preds = rfg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_log_error

# %%
mean_squared_log_error(test_label,preds)
# Out:
# 0.02759669088528923

# %%
mean_squared_log_error(test_label,preds)
# Out:
# 0.027697842994563786

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(rfg,x_train,train_label,scoring='neg_mean_squared_log_error',cv=10)

# %%
-scores
# Out:
# array([0.01880911, 0.02212209, 0.03007101, 0.01704462, 0.01474446,
#        0.02216909, 0.01704018, 0.01740383, 0.03430506, 0.01624392])

# %%
np.mean(-scores)
# Out:
# 0.020995336956268228

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [
              {'n_estimators':[100,500,1000],
               'max_features':[100,200],
               'bootstrap':[False,True]}
]

# %%
rfg_1 = RandomForestRegressor()

# %%
grid_search = GridSearchCV(rfg_1,param_grid,cv=5,scoring='neg_mean_squared_log_error',return_train_score=True)

# %%
grid_search.fit(x_train,train_label)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [False, True],
#                           'max_features': [100, 200],
#                           'n_estimators': [100, 500, 1000]}],
#              return_train_score=True, scoring='neg_mean_squared_log_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=False, max_features=100, n_estimators=1000)

# %%
rfg_best = RandomForestRegressor(n_estimators=100,
                                 bootstrap=False,max_features=100)

# %%
rfg_best.fit(x_train,train_label)
# Out:
# RandomForestRegressor(bootstrap=False, max_features=100)

# %%
preds = rfg_best.predict(x_test)

# %%
from sklearn.metrics import mean_squared_log_error

# %%
np.sqrt(mean_squared_log_error(test_label,preds))
# Out:
# 0.16292445673327058

# %%
mean_squared_log_error(test_label,preds)
# Out:
# 0.026544378601831356

# %%
prediction = rfg_best.predict(test_scaled)

# %%
submission['SalePrice'] = prediction

# %%
submission.head(20)
# Out:
#       Id  SalePrice
# 0   1461  127908.50
# 1   1462  151842.00
# 2   1463  174382.97
# 3   1464  188625.29
# 4   1465  186414.50
# 5   1466  184433.85
# 6   1467  166071.31
# 7   1468  175689.65
# 8   1469  183129.90
# 9   1470  126317.08
# 10  1471  238725.69
# 11  1472   98658.00
# 12  1473   99567.00
# 13  1474  152933.00
# 14  1475  140558.30
# 15  1476  362572.50
# 16  1477  246047.39
# 17  1478  327770.92
# 18  1479  270350.51
# 19  1480  461373.45

# %%
submission.to_csv('/content/drive/MyDrive/data/House_Price_Prediction/house-prices-advanced-regression-techniques/submission_3.csv',index=False)
